# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

dir_base = os.path.abspath(os.path.join(os.getcwd()))
sys.path.append(dir_base)

from move_folders_with_suffix import move_folders_with_suffix

# %%
move_folders_with_suffix("E:/SWAROBO/hyogwang/250902_중대형_제품_텐트_블랙매직/images")
# Out:
# Moved 250902_023511_758914_2_리빙쉘_R_1F to E:/SWAROBO/hyogwang/250902_중대형_제품_텐트_블랙매직/images\dataset\250902_2_리빙쉘_R\images\250902_023511_758914_2_리빙쉘_R_1F
# Moved 250902_023757_759525_2_리빙쉘_R_2F to E:/SWAROBO/hyogwang/250902_중대형_제품_텐트_블랙매직/images\dataset\250902_2_리빙쉘_R\images\250902_023757_759525_2_리빙쉘_R_2F
# Moved 250902_024137_358999_2_리빙쉘_R_3F to E:/SWAROBO/hyogwang/250902_중대형_제품_텐트_블랙매직/images\dataset\250902_2_리빙쉘_R\images\250902_024137_358999_2_리빙쉘_R_3F
# Moved 250902_024438_359491_2_리빙쉘_R_4F to E:/SWAROBO/hyogwang/250902_중대형_제품_텐트_블랙매직/images\dataset\250902_2_리빙쉘_R\images\250902_024438_359491_2_리빙쉘_R_4F
# Moved 250902_034225_101224_12_랜드스테이션L_R_1F to E:/SWAROBO/hyogwang/250902_중대형_제품_텐트_블랙매직/images\dataset\250902_12_랜드스테이션L_R\images\250902_034225_101224_12_랜드스테이션L_R_1F
# Moved 250902_034533_000994_12_랜드스테이션L_R_2F to E:/SWAROBO/hyogwang/250902_중대형_제품_텐트_블랙매직/images\dataset\250902_12_랜드스테이션L_R\images\250902_034533_000994_12_랜드스테이션L_R_2F
# ...
