# %% [markdown]
# # Parameters

# %%
VIDEOS_DIR = "D:/test"
FRAME_INTERVAL = 24
MULTITHREAD = True
SAMPLING_DENSITY = 1
LOSSLESS = True

# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import subprocess
from glob import glob

dir_base = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir))
sys.path.append(dir_base)

from reconstruction.utils.save_every_nth_frames_from_video import save_frames_from_videos

OUTPUT_DIR = os.path.realpath(os.path.join(VIDEOS_DIR, "data_"+os.path.basename(VIDEOS_DIR)))
VIDEOS_DIR = os.path.realpath(VIDEOS_DIR)
IMAGES_DIR = os.path.join(VIDEOS_DIR, "images")

def run(command):
    print(command)
    os.system(command)
    # subprocess.run(f'start cmd /k "{command}"', shell=False)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Batch Post Process

# %%
for folder in glob(VIDEOS_DIR):
    folder = os.path.realpath(folder)
    run(f"""\
{os.getenv("PROGRAMFILES")}\\Jawset Postshot\\bin\\postshot-cli.exe" train \
-i "{folder}\\images" \
-p "Splat ADC" \
--image-select all \
--max-image-size 0 \
--store-training-context \
-o "{folder}\\{os.path.basename(folder)}.psst" \
--export-splat-ply "{folder}\\output""")
# Out:
# C:\Program Files\Jawset Postshot\bin\postshot-cli.exe" train -i "D:\test\images" -p "Splat ADC" --image-select all --max-image-size 0 --store-training-context -o "D:\test\test.psst" --export-splat-ply "D:\test\output

# %%
run("echo 'hi'")
run("echo 'bye'")
# Out:
# echo 'hi'
# echo 'bye'
